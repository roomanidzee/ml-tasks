# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import sys
sys.path.append('..')
from src.commons.classes import Point
from src.commons.methods import generate_random_points
from src.k_means.main import generate_k_points, assign_points, update_centers

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# %%
colors = {
    0: 'blue',
    1: 'green',
    2: 'red',
    3: 'cyan',
    4: 'magenta',
    5: 'yellow',
    6: 'black',
    7: 'orange',
    8: 'pink',
    9: 'paleturquoise'
}

# %%
test_data = generate_random_points(0.0, 100.0, 100)
k_points = generate_k_points(test_data, 10)
assignments = assign_points(test_data, k_points)

# %%
fig, ax = plt.subplots()

# %%
for index, item in enumerate(k_points):
    plt.scatter(item.x, item.y, c=colors[index])

# %%
for index, item in enumerate(test_data):
    plt.scatter(item.x, item.y, c=colors[assignments[index]])

# %%
old_assignments = None

# %%
while assignments != old_assignments:
    new_centers = update_centers(test_data, assignments)
    old_assignments = assignments
    assignments = assign_points(test_data, new_centers)
    
    for index, item in enumerate(new_centers):
        plt.scatter(item.x, item.y, c=colors[index])
        
    for index, item in enumerate(test_data):
        plt.scatter(item.x, item.y, c=colors[assignments[index]])

# %%
plt.draw()

# %%
plt.show()
